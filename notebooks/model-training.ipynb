# %% [markdown]
# # Titanic Survival Prediction: Model Training
#
# Franciz Emmanuelle Angelo L. Esperanza
#
# franciz.esperanza@gmail.com
#
# Dataset: https://www.kaggle.com/competitions/titanic/overview

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
titanic_train_df = pd.read_csv('../data/train.csv')
titanic_test_df = pd.read_csv('../data/test.csv')

titanic_train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
from src.preprocess import preprocess_data

titanic_train_df = preprocess_data(titanic_train_df)
titanic_test_df = preprocess_data(titanic_test_df)

titanic_train_df
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1
# 2                               Heikkinen, Miss. Laina   1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1
# 4                             Allen, Mr. William Henry   0  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
from sklearn.model_selection import train_test_split

features = ['Pclass', 'Sex', 'AgeFilled', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'IsAlone', 'FamilySize', 'CabinCat', 'FarePerPerson', 'IsChild']

X = titanic_train_df[features]
y = titanic_train_df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

model = XGBClassifier(tree_method='hist', n_estimators=1000, enable_categorical=True, learning_rate=0.05, n_jobs=4, random_state=42)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy', n_jobs=4)

print(f"Cross-validation accuracy scores: {scores}")
print(f"Mean cross-validation accuracy: {np.mean(scores)}")
# Out:
# Cross-validation accuracy scores: [0.82517483 0.78321678 0.80985915 0.83098592 0.82394366]
# Mean cross-validation accuracy: 0.8146360681571949

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, loguniform, uniform

param_grid = {
    'max_depth': randint(1, 10),
    'min_child_weight': randint(1, 10),
    'gamma': uniform(0, 10),
    'eta': loguniform(0.05, 1),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'reg_alpha': loguniform(1e-3, 10),
    'reg_lambda': loguniform(1e-3, 10),
    'n_estimators': randint(100, 800),
    'max_delta_step': randint(0, 10),
    'tree_method': ['approx', 'hist']
}

grid = RandomizedSearchCV(model, n_jobs=4, param_distributions=param_grid, scoring='accuracy', cv=5, n_iter=50, random_state=42, error_score='raise')
grid.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise',
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=True,
#                                            eval_metric=None, feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            in...
# ...

# %%
best_model = grid.best_estimator_
best_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=np.float64(0.7769408918924418), device=None,
#               early_stopping_rounds=None, enable_categorical=True,
#               eta=np.float64(0.10255115385067451), eval_metric=None,
#               feature_types=None, feature_weights=None,
#               gamma=np.float64(0.9387329008129175), grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=8, max_depth=40,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=371,
#               n_jobs=4, ...)

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8315079286910272
# {'colsample_bytree': np.float64(0.7769408918924418), 'eta': np.float64(0.10255115385067451), 'gamma': np.float64(0.9387329008129175), 'max_delta_step': 8, 'max_depth': 40, 'min_child_weight': 5, 'n_estimators': 371, 'reg_alpha': np.float64(0.00044695759020693004), 'reg_lambda': np.float64(0.008203552400310316), 'subsample': np.float64(0.7742691594711564), 'tree_method': 'approx'}

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

pred = best_model.predict(X_test)

print(classification_report(y_test, pred, target_names=['Not Survived', 'Survived']))
# Out:
#               precision    recall  f1-score   support
#
# Not Survived       0.82      0.88      0.85       110
#     Survived       0.79      0.70      0.74        69
#
#     accuracy                           0.81       179
#    macro avg       0.80      0.79      0.79       179
# weighted avg       0.81      0.81      0.81       179

# %%
f_imp = pd.Series(best_model.feature_importances_, index=features).sort_values()

fig,ax=plt.subplots(figsize=(7,5))
f_imp.plot.barh(ax=ax)
# Out:
# <Axes: >

# %%
pred_df = titanic_test_df[features]
final_pred = best_model.predict(pred_df)

final_pred_doc = pd.DataFrame ({
    'PassengerId': titanic_test_df['PassengerId'],
    'Survived': final_pred
})

final_pred_doc.to_csv('final_pred_doc.csv', index=False)
final_pred_doc
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
